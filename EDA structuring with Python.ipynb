# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('eda_using_basic_data_functions_in_python_dataset1.csv')
df.head()
# Out:
#        date  number_of_strikes center_point_geom
# 0  1/3/2018                194     POINT(-75 27)
# 1  1/3/2018                 41   POINT(-78.4 29)
# 2  1/3/2018                 33   POINT(-73.9 27)
# 3  1/3/2018                 38   POINT(-73.8 27)
# 4  1/3/2018                 92     POINT(-79 28)

# %%
# Convert the `date` column to datetime.
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)

# %%
df.shape
# Out:
# (586027, 3)

# %%
df.drop_duplicates().shape
# Out:
# (586027, 3)

# %%
df.sort_values('number_of_strikes', ascending=False).head(10)
# Out:
#              date  number_of_strikes  center_point_geom
# 302758 2018-08-20               2211  POINT(-92.5 35.5)
# 278383 2018-08-16               2142  POINT(-96.1 36.1)
# 280830 2018-08-17               2061  POINT(-90.2 36.1)
# 280453 2018-08-17               2031  POINT(-89.9 35.9)
# 278382 2018-08-16               1902  POINT(-96.2 36.1)
# 11517  2018-02-10               1899  POINT(-95.5 28.1)
# 277506 2018-08-16               1878  POINT(-89.7 31.5)
# 24906  2018-02-25               1833  POINT(-98.7 28.9)
# 284320 2018-08-17               1767    POINT(-90.1 36)
# 24825  2018-02-25               1741      POINT(-98 29)

# %%
df.center_point_geom.value_counts()
# Out:
# center_point_geom
# POINT(-82.5 22.9)     47
# POINT(-82.3 22.9)     46
# POINT(-82.4 22.9)     42
# POINT(-84.1 22.5)     40
# POINT(-84.2 22.4)     40
#                       ..
# POINT(-107.7 43.4)     1
# POINT(-108.6 43.5)     1
# POINT(-106.7 43.5)     1
# POINT(-106.5 43.5)     1
# POINT(-112 40.2)       1
# Name: count, Length: 131487, dtype: int64

# %%
df.center_point_geom.value_counts()[:20].rename_axis('unique_values').reset_index(name='counts').style.background_gradient()
# Out:
# <style type="text/css">
# #T_ad1f6_row0_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ad1f6_row1_col1 {
#   background-color: #034b76;
#   color: #f1f1f1;
# }
# #T_ad1f6_row2_col1 {
#   background-color: #2f8bbe;
#   color: #f1f1f1;
# }
# #T_ad1f6_row3_col1, #T_ad1f6_row4_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_ad1f6_row5_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_ad1f6_row6_col1, #T_ad1f6_row7_col1 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_ad1f6_row8_col1, #T_ad1f6_row9_col1, #T_ad1f6_row10_col1, #T_ad1f6_row11_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ad1f6_row12_col1, #T_ad1f6_row13_col1, #T_ad1f6_row14_col1, #T_ad1f6_row15_col1, #T_ad1f6_row16_col1, #T_ad1f6_row17_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_ad1f6_row18_col1, #T_ad1f6_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ad1f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad1f6_level0_col0" class="col_heading level0 col0" >unique_values</th>
#       <th id="T_ad1f6_level0_col1" class="col_heading level0 col1" >counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad1f6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad1f6_row0_col0" class="data row0 col0" >POINT(-82.5 22.9)</td>
#       <td id="T_ad1f6_row0_col1" class="data row0 col1" >47</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad1f6_row1_col0" class="data row1 col0" >POINT(-82.3 22.9)</td>
#       <td id="T_ad1f6_row1_col1" class="data row1 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad1f6_row2_col0" class="data row2 col0" >POINT(-82.4 22.9)</td>
#       <td id="T_ad1f6_row2_col1" class="data row2 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad1f6_row3_col0" class="data row3 col0" >POINT(-84.1 22.5)</td>
#       <td id="T_ad1f6_row3_col1" class="data row3 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad1f6_row4_col0" class="data row4 col0" >POINT(-84.2 22.4)</td>
#       <td id="T_ad1f6_row4_col1" class="data row4 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad1f6_row5_col0" class="data row5 col0" >POINT(-84.2 22.3)</td>
#       <td id="T_ad1f6_row5_col1" class="data row5 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad1f6_row6_col0" class="data row6 col0" >POINT(-82 22.9)</td>
#       <td id="T_ad1f6_row6_col1" class="data row6 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad1f6_row7_col0" class="data row7 col0" >POINT(-82.7 22.9)</td>
#       <td id="T_ad1f6_row7_col1" class="data row7 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad1f6_row8_col0" class="data row8 col0" >POINT(-82.6 22.9)</td>
#       <td id="T_ad1f6_row8_col1" class="data row8 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ad1f6_row9_col0" class="data row9 col0" >POINT(-81.9 22.9)</td>
#       <td id="T_ad1f6_row9_col1" class="data row9 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ad1f6_row10_col0" class="data row10 col0" >POINT(-83.4 22.8)</td>
#       <td id="T_ad1f6_row10_col1" class="data row10 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ad1f6_row11_col0" class="data row11 col0" >POINT(-82.4 23)</td>
#       <td id="T_ad1f6_row11_col1" class="data row11 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ad1f6_row12_col0" class="data row12 col0" >POINT(-80.7 22.3)</td>
#       <td id="T_ad1f6_row12_col1" class="data row12 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ad1f6_row13_col0" class="data row13 col0" >POINT(-84.1 22.4)</td>
#       <td id="T_ad1f6_row13_col1" class="data row13 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ad1f6_row14_col0" class="data row14 col0" >POINT(-84.3 22.3)</td>
#       <td id="T_ad1f6_row14_col1" class="data row14 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ad1f6_row15_col0" class="data row15 col0" >POINT(-84 22.5)</td>
#       <td id="T_ad1f6_row15_col1" class="data row15 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ad1f6_row16_col0" class="data row16 col0" >POINT(-82.1 22.9)</td>
#       <td id="T_ad1f6_row16_col1" class="data row16 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ad1f6_row17_col0" class="data row17 col0" >POINT(-82.3 23)</td>
#       <td id="T_ad1f6_row17_col1" class="data row17 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ad1f6_row18_col0" class="data row18 col0" >POINT(-82.8 22.8)</td>
#       <td id="T_ad1f6_row18_col1" class="data row18 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_ad1f6_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ad1f6_row19_col0" class="data row19 col0" >POINT(-82.2 28.1)</td>
#       <td id="T_ad1f6_row19_col1" class="data row19 col1" >33</td>
#     </tr>
#   </tbody>
# </table>
